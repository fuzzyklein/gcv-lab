# %% [markdown]
# # 3D Plotting

# %%
from IPython.display import Latex
from matplotlib.pyplot import *
from mpl_toolkits.mplot3d import Axes3D
from numpy import *
from sympy import latex, simplify, solve, symbols

# %%
def fun(x, y):
    return x**2 + y

fig = figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-76d87e69301e> in <module>
#      14 ax.set_ylabel('Y Label')
#      15 ax.set_zlabel('Z Label')
# ---> 16 ax.equal()
#      17 show()
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'equal'

# %%
x,y = symbols("x,y")
X = linspace(-4, 4.05, 128)
Y = X
F = [x**2 + y, x + y]
s = r'$$\begin{align}' + '\n'
for i, f in enumerate(F):
    s += f"f_{i+1}={latex(F[i])}." + '\n' + (r'\\' if len(F) > i+1 else r'\end{align}$$')
Latex(s)
# Out:
# $$\begin{align}
# f_1=x^{2} + y.
# \\f_2=x + y.
# \end{align}$$

# %%
xlabel("$x$")
ylabel("$y$")
grid(True)
axis('equal')
axis([-5, 5, 0, 16])
axis(False)
labels = list()
for f in F:
    Z = [f.evalf(subs={x:x0,y:y0}) for x0, y0 x0 in X]
    labels.append(f"${latex(f)}$")
    Axes3D.plot_surface(X,Y)
legend(labels=labels)
S = solve(F[0]-F[1])
for i in range(len(S)):
    annotate(rf"$\left({latex(S[i])}, {latex(F[i].subs({x:S[i]}))}\right)$",
             xy=(S[i].evalf(), F[i].evalf(subs={x:S[i]})))
Latex(f'$$S={latex(S)}.$$')
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-a2c11b0c71fe> in <module>
#       7 labels = list()
#       8 for f in F:
# ----> 9     Z = [f.evalf(subs={x:x0,y:y0}) for y0 in Y for x0 in X]
#      10     labels.append(f"${latex(f)}$")
#      11     Axes3D.plot(X,Y)
#
# <ipython-input-6-a2c11b0c71fe> in <listcomp>(.0)
#       7 labels = list()
#       8 for f in F:
# ----> 9     Z = [f.evalf(subs={x:x0,y:y0}) for y0 in Y for x0 in X]
#      10     labels.append(f"${latex(f)}$")
#      11     Axes3D.plot(X,Y)
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1459             options['quad'] = quad
#    1460         try:
# -> 1461             result = evalf(self, prec + 4, options)
#    1462         except NotImplementedError:
#    1463             # Fall back to the ordinary evalf
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1311     try:
#    1312         rf = evalf_table[x.func]
# -> 1313         r = rf(x, prec, options)
#    1314     except KeyError:
#    1315         # Fall back to ordinary evalf if possible
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf_add(v, prec, options)
#     523         options['maxprec'] = min(oldmaxprec, 2*prec)
#     524
# --> 525         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     526         re, re_acc = add_terms(
#     527             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in <listcomp>(.0)
#     523         options['maxprec'] = min(oldmaxprec, 2*prec)
#     524
# --> 525         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     526         re, re_acc = add_terms(
#     527             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1311     try:
#    1312         rf = evalf_table[x.func]
# -> 1313         r = rf(x, prec, options)
#    1314     except KeyError:
#    1315         # Fall back to ordinary evalf if possible
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf_symbol(x, prec, options)
#    1241         if cached_prec >= prec:
#    1242             return cached
# -> 1243         v = evalf(sympify(val), prec, options)
#    1244         cache[x] = (v, prec)
#    1245         return v
#
# ... last 5 frames repeated, from the frame below ...
#
# c:\users\owner\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1311     try:
#    1312         rf = evalf_table[x.func]
# -> 1313         r = rf(x, prec, options)
#    1314     except KeyError:
#    1315         # Fall back to ordinary evalf if possible
#
# RecursionError: maximum recursion depth exceeded

# %%
show()

# %%
help(axis)
# Out:
# Help on function axis in module matplotlib.pyplot:
#
# axis(*args, emit=True, **kwargs)
#     Convenience method to get or set some axis properties.
#
#     Call signatures::
#
#       xmin, xmax, ymin, ymax = axis()
#       xmin, xmax, ymin, ymax = axis([xmin, xmax, ymin, ymax])
#       xmin, xmax, ymin, ymax = axis(option)
#       xmin, xmax, ymin, ymax = axis(**kwargs)
#
#     Parameters
#     ----------
#     xmin, xmax, ymin, ymax : float, optional
#         The axis limits to be set.  This can also be achieved using ::
#
#             ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))
#
#     option : bool or str
#         If a bool, turns axis lines and labels on or off. If a string,
#         possible values are:
#
#         ======== ==========================================================
#         Value    Description
#         ======== ==========================================================
#         'on'     Turn on axis lines and labels. Same as ``True``.
#         'off'    Turn off axis lines and labels. Same as ``False``.
#         'equal'  Set equal scaling (i.e., make circles circular) by
#                  changing axis limits. This is the same as
#                  ``ax.set_aspect('equal', adjustable='datalim')``.
#                  Explicit data limits may not be respected in this case.
#         'scaled' Set equal scaling (i.e., make circles circular) by
#                  changing dimensions of the plot box. This is the same as
#                  ``ax.set_aspect('equal', adjustable='box', anchor='C')``.
#                  Additionally, further autoscaling will be disabled.
#         'tight'  Set limits just large enough to show all data, then
#                  disable further autoscaling.
#         'auto'   Automatic scaling (fill plot box with data).
#         'image'  'scaled' with axis limits equal to data limits.
#         'square' Square plot; similar to 'scaled', but initially forcing
#                  ``xmax-xmin == ymax-ymin``.
#         ======== ==========================================================
#
#     emit : bool, default: True
#         Whether observers are notified of the axis limit change.
#         This option is passed on to `~.Axes.set_xlim` and
#         `~.Axes.set_ylim`.
#
#     Returns
#     -------
#     xmin, xmax, ymin, ymax : float
#         The axis limits.
#
#     See Also
#     --------
#     matplotlib.axes.Axes.set_xlim
#     matplotlib.axes.Axes.set_ylim
