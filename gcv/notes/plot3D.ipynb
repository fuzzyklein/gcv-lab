# %% [markdown]
# # 3D Plotting

# %%
from pathlib import Path

# %%
from IPython.display import Latex
from matplotlib.pyplot import *
import matplotlib.cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from sympy import latex, simplify, solve, symbols

# %%
exec((Path('../../../py/startup.py').read_text()))
# Out:
# hello world

# %%
X = np.linspace(-12, 12, 128)
Y = X
X,Y = np.meshgrid(X,Y)

# %%
fig, ax = subplots(subplot_kw={"projection": "3d"})
Z = np.sin(np.sqrt(X**2 + Y**2))
surface = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=1, antialiased=True)
fig.colorbar(surface, shrink=.5, aspect=5)
xlabel("$x$")
ylabel("$y$")
grid(True)

show()

# %%
import mpl_toolkits.mplot3d as mp3d
public(mp3d)
# Out:
# Axes3D  art3d  axes3d  axis3d  proj3d

# %%
public(mp3d.art3d)
# Out:
# Line3D             Poly3DCollection          mpath
# Line3DCollection   PolyCollection            mtext
# LineCollection     Text3D                    np
# Normalize          artist                    patch_2d_to_3d
# Patch              get_dir_vector            patch_collection_2d_to_3d
# Patch3D            juggle_axes               pathpatch_2d_to_3d
# Patch3DCollection  line_2d_to_3d             poly_collection_2d_to_3d
# PatchCollection    line_collection_2d_to_3d  proj3d
# Path3DCollection   lines                     rotate_axes
# PathCollection     math                      text_2d_to_3d
# PathPatch3D        mcolors
